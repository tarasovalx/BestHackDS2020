# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

plt.style.use('ggplot')

# %matplotlib inline

# %%
data=pd.read_excel('data/train.xlsx')
data
# Out:
#                                               Shrt_Desc  Water_(g)  \
# 0                    BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY       4.70
# 1                                 HEARTS OF PALM,CANNED      90.20
# 2     CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD...      63.89
# 3               PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD      54.73
# 4                                     VINEGAR,DISTILLED      94.78
# ...                                                 ...        ...
# 7751                                DRUM,FRESHWATER,RAW      77.33
# 7752       BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW      63.95
# 7753  POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE U...      74.00
# 7754              APPLES,DEHYD (LO MOIST),SULFURED,STWD      79.36
# 7755                           TUNA,FRESH,YELLOWFIN,RAW      74.03
#
#       Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0            393        12.00           6.00     3.90           73.40
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7756 entries, 0 to 7755
# Data columns (total 52 columns):
# Shrt_Desc            7756 non-null object
# Water_(g)            7751 non-null float64
# Energ_Kcal           7756 non-null int64
# Protein_(g)          7756 non-null float64
# Lipid_Tot_(g)        7756 non-null float64
# Ash_(g)              7461 non-null float64
# Carbohydrt_(g)       7756 non-null float64
# Fiber_TD_(g)         7168 non-null float64
# Sugar_Tot_(g)        6013 non-null float64
# Calcium_(mg)         7443 non-null float64
# Iron_(mg)            7630 non-null float64
# Magnesium_(mg)       7139 non-null float64
# Phosphorus_(mg)      7234 non-null float64
# Potassium_(mg)       7390 non-null float64
# Sodium_(mg)          7681 non-null float64
# Zinc_(mg)            7123 non-null float64
# Copper_mg)           6630 non-null float64
# Manganese_(mg)       5828 non-null float64
# Selenium_(µg)        6175 non-null float64
# ...

# %%
data
# Out:
#                                               Shrt_Desc  Water_(g)  \
# 0                    BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY       4.70
# 1                                 HEARTS OF PALM,CANNED      90.20
# 2     CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD...      63.89
# 3               PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD      54.73
# 4                                     VINEGAR,DISTILLED      94.78
# ...                                                 ...        ...
# 7751                                DRUM,FRESHWATER,RAW      77.33
# 7752       BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW      63.95
# 7753  POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE U...      74.00
# 7754              APPLES,DEHYD (LO MOIST),SULFURED,STWD      79.36
# 7755                           TUNA,FRESH,YELLOWFIN,RAW      74.03
#
#       Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0            393        12.00           6.00     3.90           73.40
# ...

# %%
fig, ax = plt.subplots(figsize=(20,12))
sns_heatmap = sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
na_ser = data.isna().sum()
high_na_vals = []
for i, val in enumerate(na_ser):
    if val > 2500:
        high_na_vals.append(na_ser.index[i])
high_na_vals = high_na_vals[:-2]

# %%
high_na_vals
# Out:
# ['Choline_Tot_ (mg)',
#  'Alpha_Carot_(µg)',
#  'Beta_Carot_(µg)',
#  'Beta_Crypt_(µg)',
#  'Lycopene_(µg)',
#  'Lut+Zea_ (µg)',
#  'Vit_E_(mg)',
#  'Vit_D_µg',
#  'Vit_D_IU',
#  'Vit_K_(µg)']

# %%
real_vars = list(set(data.columns) - set(['Shrt_Desc', 'GmWt_Desc1', 'GmWt_Desc2']))
real_vars
# Out:
# ['Zinc_(mg)',
#  'Manganese_(mg)',
#  'Niacin_(mg)',
#  'Carbohydrt_(g)',
#  'Potassium_(mg)',
#  'Sodium_(mg)',
#  'Folic_Acid_(µg)',
#  'Fiber_TD_(g)',
#  'Alpha_Carot_(µg)',
#  'Copper_mg)',
#  'Retinol_(µg)',
#  'FA_Mono_(g)',
#  'Vit_K_(µg)',
#  'Selenium_(µg)',
#  'Phosphorus_(mg)',
#  'Vit_D_µg',
#  'Panto_Acid_mg)',
#  'Iron_(mg)',
#  'Ash_(g)',
#  'Lycopene_(µg)',
#  'Vit_A_RAE',
#  'Vit_C_(mg)',
#  'Water_(g)',
#  'Vit_A_IU',
#  'Beta_Carot_(µg)',
#  'Protein_(g)',
#  'GmWt_1',
#  'Vit_D_IU',
#  'Sugar_Tot_(g)',
#  'Calcium_(mg)',
#  'Magnesium_(mg)',
#  'Vit_E_(mg)',
#  'FA_Sat_(g)',
#  'Folate_DFE_(µg)',
#  'Vit_B6_(mg)',
#  'Refuse_Pct',
#  'GmWt_2',
#  'Energ_Kcal',
#  'FA_Poly_(g)',
#  'Choline_Tot_ (mg)',
#  'Lut+Zea_ (µg)',
#  'Thiamin_(mg)',
#  'Folate_Tot_(µg)',
#  'Food_Folate_(µg)',
#  'Riboflavin_(mg)',
#  'Vit_B12_(µg)',
#  'Beta_Crypt_(µg)',
#  'Cholestrl_(mg)',
#  'Lipid_Tot_(g)']

# %%
real_vars_hist = data[real_vars].hist(figsize=(20, 20))

# %%
vars_to_log = [
            'Zinc_(mg)',
            'Manganese_(mg)',
            'Niacin_(mg)',
            'Potassium_(mg)',
            'Sodium_(mg)',
            'Folic_Acid_(µg)',
            'Fiber_TD_(g)',
            'Alpha_Carot_(µg)',
            'Copper_mg)',
            'Retinol_(µg)',
            'FA_Mono_(g)',
            'Vit_K_(µg)',
            'Selenium_(µg)',
            'Phosphorus_(mg)',
            'Vit_D_µg',
            'Panto_Acid_mg)',
            'Iron_(mg)',
            'Ash_(g)',
            'Lycopene_(µg)',
            'Vit_A_RAE',
            'Vit_C_(mg)',
            'Vit_A_IU',
            'Beta_Carot_(µg)',
            'Vit_D_IU',
            'Calcium_(mg)',
            'Cholestrl_(mg)',
            'Magnesium_(mg)',
            'Vit_E_(mg)',
            'FA_Sat_(g)',
            'Folate_DFE_(µg)',
            'Vit_B6_(mg)',
            'FA_Poly_(g)',
            'Choline_Tot_ (mg)',
            'Lut+Zea_ (µg)',
            'Thiamin_(mg)',
            'Folate_Tot_(µg)',
            'Food_Folate_(µg)',
            'Riboflavin_(mg)',
            'Vit_B12_(µg)',
            'Beta_Crypt_(µg)',
]
#data[high_na_vals] = data[high_na_vals].apply(lambda w: np.log(w + 1))

# %%
real_vars_hist = data[vars_to_log].hist(figsize=(20, 20))

# %%
data[vars_to_log] = data[vars_to_log].apply(lambda w: np.log(w + 1))
real_vars_hist = data[vars_to_log].hist(figsize=(20, 20))

# %%
df = data.dropna().copy()
names = df['Shrt_Desc']
df.drop(columns=['Shrt_Desc', 'GmWt_1', 'GmWt_2', 'GmWt_Desc1', 'GmWt_Desc2', 'Refuse_Pct', 'Vit_D_IU', 'Ash_(g)',
                                 'Energ_Kcal',
#                 'Carbohydrt(g)',
                 'Lipid_Tot_(g)',
#                'Protein(g)',
#                 'Water(g)',
#                 'FiberTD(g)',
                             'Zinc_(mg)',
             'Manganese_(mg)',
             'Niacin_(mg)',
             'Potassium_(mg)',
             'Sodium_(mg)',
#             'FolicAcid(µg)',
             'Alpha_Carot_(µg)',
             'Copper_mg)',
             'Retinol_(µg)',
             'FA_Mono_(g)',
             'Vit_K_(µg)',
             'Selenium_(µg)',
#             'Phosphorus(mg)',
             'Vit_D_µg',
             'Panto_Acid_mg)',
             'Iron_(mg)',
             'Lycopene_(µg)',
#             'Vit_A_RAE',
             'Vit_C_(mg)',
#             'Vit_A_IU',
             'Beta_Carot_(µg)',
             'Vit_D_IU',
#             'Calcium(mg)',
#             'Magnesium_(mg)',
             'Vit_E_(mg)',
#             'FASat(g)',
             'Folate_DFE_(µg)',
             'Vit_B6_(mg)',
#             'FAPoly(g)',
             'Choline_Tot_ (mg)',
             'Lut+Zea_ (µg)',
             'Thiamin_(mg)',
             'Folate_Tot_(µg)',
             'Food_Folate_(µg)',
             'Riboflavin_(mg)',
#             'VitB12(µg)',
             'Beta_Crypt_(µg)',
#
#'SugarTot(g)',
'Cholestrl_(mg)'
], inplace = True, axis = 0)
df.dropna(0, inplace = True)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler = StandardScaler()
scaler.fit(df)
scaled_df = scaler.transform(df)

# %%
df_scaled = pd.DataFrame(scaled_df)
df_scaled.columns = df.columns
df_scaled
# Out:
#       Water_(g)  Protein_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0     -0.106804     0.665354       -0.708286     -0.776803      -0.490281
# 1      1.280635    -1.130528       -0.706661     -0.776803      -0.487537
# 2     -0.873447    -0.506408        1.428672      0.586535      -0.477933
# 3     -1.689283    -0.726169        1.672025      1.204815       2.678163
# 4     -1.275302    -0.998672        1.432735      0.827331       2.253554
# ...         ...          ...             ...           ...            ...
# 1962   1.295878    -1.030317       -0.599001      0.110756      -0.372982
# 1963   0.807070     0.209131       -0.708286     -0.776803      -0.490281
# 1964   0.403482     0.702274       -0.708286     -0.776803      -0.490281
# 1965   0.539975    -1.121738        0.352067      0.110756       0.456342
# 1966   0.561800     1.014334       -0.708286     -0.776803      -0.490281
#
#       Calcium_(mg)  Magnesium_(mg)  Phosphorus_(mg)  Folic_Acid_(µg)  \
# ...

# %%
def threshold_scale(w):
    if(w > 1.25):
        return w ** 6
    return w

df_scaled['Water_(g)'] = df_scaled['Water_(g)'].apply(threshold_scale) * 2
df_scaled['Carbohydrt_(g)'] = df_scaled['Carbohydrt_(g)'] * 3
df_scaled['Calcium_(mg)'] = df_scaled['Calcium_(mg)'] * 3
df_scaled['Fiber_TD_(g)'] = df_scaled['Fiber_TD_(g)'] * 3
#df_scaled['Vit_A_RAE'] = df_scaled['Vit_A_RAE'] * 1.5

# %%
df_scaled.describe()
# Out:
#          Water_(g)   Protein_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# count  1967.000000  1.967000e+03    1.967000e+03  1.967000e+03   1.967000e+03
# mean      0.319608  1.457344e-16   -2.413479e-16 -2.664084e-16  -1.664206e-16
# std       2.998771  1.000254e+00    3.000763e+00  3.000763e+00   1.000254e+00
# min      -4.005598 -1.130528e+00   -2.124859e+00 -2.330410e+00  -4.902805e-01
# 25%      -1.164551 -9.371388e-01   -2.124859e+00 -2.330410e+00  -4.902805e-01
# 50%       0.506266 -2.444540e-01   -1.471584e+00 -2.330410e+00  -4.175689e-01
# 75%       1.503976  8.490737e-01    5.644176e-01  2.015794e+00  -4.783716e-02
# max      19.212586  6.394068e+00    1.006068e+01  1.300720e+01   6.355587e+00
#
#        Calcium_(mg)  Magnesium_(mg)  Phosphorus_(mg)  Folic_Acid_(µg)  \
# count  1.967000e+03    1.967000e+03     1.967000e+03     1.967000e+03
# mean  -1.801643e-16   -4.247859e-16     4.498463e-17     5.136263e-18
# ...

# %% [markdown]
# # KNN clustering

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters = 5)
model.fit(df_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(random_state=1, perplexity=30)
tsne_repr=tsne.fit_transform(scaled_df)

# %%
plt.scatter(tsne_repr[:,0],tsne_repr[:,1], c = model.labels_, cmap = 'viridis')

# %% [markdown]
# # AgglomerativeClustering

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
cluster.fit(scaled_df)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=5,
#                         pooling_func='deprecated')

# %%
plt.scatter(tsne_repr[:,0],tsne_repr[:,1], c = cluster.labels_, cmap = 'viridis')

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN

db_cluster = DBSCAN(algorithm = 'brute',eps=1 ,min_samples=10)
db_cluster.fit(scaled_df)
# Out:
# DBSCAN(algorithm='brute', eps=1, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=10, n_jobs=None, p=None)

# %%
plt.scatter(tsne_repr[:,0],tsne_repr[:,1], c = db_cluster.labels_, cmap = 'viridis')

# %%
df_scaled = pd.DataFrame(scaled_df)
df_scaled.columns = df.columns
df_scaled['name'] = names.reset_index(drop = True)
df_scaled['label'] =  cluster.labels_
df_scaled
# Out:
#       Water_(g)  Protein_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0     -0.213609     0.665354       -2.124859     -2.330410      -0.490281
# 1      8.822324    -1.130528       -2.119984     -2.330410      -0.487537
# 2     -1.746895    -0.506408        4.286016      1.759604      -0.477933
# 3     -3.378565    -0.726169        5.016076      3.614446       2.678163
# 4     -2.550605    -0.998672        4.298204      2.481994       2.253554
# ...         ...          ...             ...           ...            ...
# 1962   9.471419    -1.030317       -1.797003      0.332268      -0.372982
# 1963   1.614140     0.209131       -2.124859     -2.330410      -0.490281
# 1964   0.806965     0.702274       -2.124859     -2.330410      -0.490281
# 1965   1.079949    -1.121738        1.056202      0.332268       0.456342
# 1966   1.123599     1.014334       -2.124859     -2.330410      -0.490281
#
#       Calcium_(mg)  Magnesium_(mg)  Phosphorus_(mg)  Folic_Acid_(µg)  \
# ...

# %%
df_scaled['label'].value_counts().plot.pie(cmap = 'viridis')

# %%
df_scaled.groupby('label').mean().T.plot.barh(figsize=[10,40], cmap = 'viridis')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df_scaled.groupby('label')['name'].value_counts()[3])
# Out:
# name
# BABYFOOD,MEAT,BF,STR                                            2
# BEEF,CHUCK,UNDER BLADE CNTR STEAK,BNLESS,DENVER CUT,LN,0" FA    2
# ALCOHOLIC BEV,LIQUEUR,COFFEE W/CRM,34 PROOF                     1
# BABYFOOD,MEAT,LAMB,STR                                          1
# BABYFOOD,MEAT,TURKEY,JR                                         1
# BABYFOOD,MEAT,TURKEY,STR                                        1
# BABYFOOD,MEAT,VEAL,STR                                          1
# BEEF, CHUCK, SHORT RIBS, BNL, 0" FAT, CHOICE, CKED, BR          1
# BEEF,BRISKET,FLAT HALF,BNLESS LN,0" FAT,ALL GRDS,RAW            1
# BEEF,BRISKET,FLAT HALF,BNLESS,LN & FAT,0" FAT,ALL GRDS,RAW      1
# BEEF,BRISKET,FLAT HALF,BNLESS,LN & FAT,0" FAT,CHOIC,RAW         1
# BEEF,BRISKET,FLAT HALF,BNLESS,LN & FAT,0" FAT,SEL,RAW           1
# BEEF,BRISKET,FLAT HALF,BNLESS,LN,0" FAT,SEL,RAW                 1
# BEEF,BRISKET,FLAT HALF,LN & FAT,1/8" FAT,SEL,CKD,BRSD           1
# ...

# %%
data
def save_cluster(name, df):
    d = pd.DataFrame(data.columns) 
    d['name'] = df['name']
    d['label'] = df['label']
    d[data.columns] = data[data['Shrt_Desc'] == df['name']]
    return d
save_cluster('s', df_scaled['name', 'label'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1333-e23a4898ab7b> in <module>
#       6     d[data.columns] = data[data['Shrt_Desc'] == df['name']]
#       7     return d
# ----> 8 save_cluster('s', df_scaled)
#
# <ipython-input-1333-e23a4898ab7b> in save_cluster(name, df)
#       4     d['name'] = df['name']
#       5     d['label'] = df['label']
# ----> 6     d[data.columns] = data[data['Shrt_Desc'] == df['name']]
#       7     return d
#       8 save_cluster('s', df_scaled)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1140
#    1141         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1142             raise ValueError("Can only compare identically-labeled " "Series objects")
#    1143
#    1144         elif is_categorical_dtype(self):
#
# ...
