# %%
import pandas as pd
import seaborn as sns
import matplotlib
from scipy import stats
from scipy.stats import norm, skew

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %matplotlib inline

# %%
data = pd.read_excel('data/predictions.xlsx')
data
# Out:
#                                               Shrt_Desc  Water_(g)  \
# 0                    BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY       4.70
# 1                                 HEARTS OF PALM,CANNED      90.20
# 2     CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD...      63.89
# 3               PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD      54.73
# 4                                     VINEGAR,DISTILLED      94.78
# ...                                                 ...        ...
# 7751                                DRUM,FRESHWATER,RAW      77.33
# 7752       BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW      63.95
# 7753  POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE U...      74.00
# 7754              APPLES,DEHYD (LO MOIST),SULFURED,STWD      79.36
# 7755                           TUNA,FRESH,YELLOWFIN,RAW      74.03
#
#       Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0            393        12.00           6.00     3.90           73.40
# 1             28         2.52           0.62     2.04            4.62
# 2            196        24.06          11.09     1.56            0.00
# 3            280        20.43          21.35     3.51            0.00
# 4             18         0.00           0.00     0.02            0.04
# ...          ...          ...            ...      ...             ...
# 7751         119        17.54           4.93     1.08            0.00
# 7752         224        20.59          15.04     0.87            0.00
# 7753         132         5.06           7.59     2.09           11.27
# 7754          74         0.28           0.12     0.33           19.91
# 7755         109        24.40           0.49     1.64            0.00
#
#       Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  ...  Vit_D_µg  Vit_D_IU  \
# 0              5.2          13.75         651.0  ...       0.0       0.0
# 1              2.4            NaN          58.0  ...       0.0       0.0
# 2              0.0           0.00          13.0  ...       NaN       NaN
# 3              0.0           0.00          10.0  ...       0.7      29.0
# 4              0.0           0.04           6.0  ...       0.0       0.0
# ...            ...            ...           ...  ...       ...       ...
# 7751           0.0            NaN          60.0  ...       NaN       NaN
# 7752           0.0           0.00          23.0  ...       NaN       NaN
# 7753           1.8            NaN         119.0  ...       0.0       0.0
# 7754           2.6            NaN           4.0  ...       0.0       0.0
# 7755           0.0           0.00           4.0  ...       1.7      69.0
#
#       Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)  \
# 0            3.0       1.267        1.429        2.186             0.0
# 1            NaN       0.130        0.103        0.202             0.0
# 2            0.0       2.866        4.878        1.673           130.0
# 3            0.0       7.670       10.140        2.320            58.0
# 4            0.0       0.000        0.000        0.000             0.0
# ...          ...         ...          ...          ...             ...
# 7751         NaN       1.119        2.190        1.154            64.0
# 7752         1.6       6.067        6.438        0.572            80.0
# 7753         NaN       3.530        2.587        1.076            15.0
# 7754         NaN       0.020        0.005        0.036             0.0
# 7755         0.1       0.172        0.116        0.147            39.0
#
#       Refuse_Pct  label                                              probs
# 0            0.0      0  [0.9998394250869751, 3.4087479434674606e-05, 0...
# 1            0.0      1  [2.999854586960282e-08, 0.9994088411331177, 4....
# 2           29.0      3  [2.9562095733126625e-05, 7.411003025481477e-05...
# 3           27.0      3  [0.00026382150826975703, 0.0006710545276291668...
# 4            0.0      4  [1.605821307748556e-05, 0.028907138854265213, ...
# ...          ...    ...                                                ...
# 7751         0.0      3  [0.00042958883568644524, 0.0012661732034757733...
# 7752         9.0      3  [7.852991984691471e-05, 0.00026358681498095393...
# 7753         0.0      1  [0.000639920006506145, 0.8160973191261292, 0.1...
# 7754         0.0      1  [4.736647740699595e-10, 0.9999643564224243, 3....
# 7755         0.0      3  [9.45131469052285e-05, 0.0001476598990848288, ...
#
# [7756 rows x 50 columns]

# %%
vars_ = ['Protein_(g)', 'Lipid_Tot_(g)', 'Carbohydrt_(g)', 'label', 'Energ_Kcal']
df = data[vars_]
df
# Out:
#       Protein_(g)  Lipid_Tot_(g)  Carbohydrt_(g)  label  Energ_Kcal
# 0           12.00           6.00           73.40      0         393
# 1            2.52           0.62            4.62      1          28
# 2           24.06          11.09            0.00      3         196
# 3           20.43          21.35            0.00      3         280
# 4            0.00           0.00            0.04      4          18
# ...           ...            ...             ...    ...         ...
# 7751        17.54           4.93            0.00      3         119
# 7752        20.59          15.04            0.00      3         224
# 7753         5.06           7.59           11.27      1         132
# 7754         0.28           0.12           19.91      1          74
# 7755        24.40           0.49            0.00      3         109
#
# [7756 rows x 5 columns]

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import max_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV





for i in range(5):
    data_x = df[df['label'] == i][['Protein_(g)', 'Lipid_Tot_(g)', 'Carbohydrt_(g)', 'Energ_Kcal']]
    x_train, x_test, y_train, y_test = train_test_split(data_x.drop(columns=['Energ_Kcal']), data_x['Energ_Kcal'], test_size=0.15, random_state=0)
    model = Lasso(random_state=0, max_iter= 1000)
    param_grid = {
        'alpha': [0.0001, 0.001, 0.01, 0.05, 0.1, 0.5, 0.8, 1, 5, 10, 20,50,100],
    }
    grid_cv_lasso = GridSearchCV(model, param_grid, cv = 5, scoring='neg_mean_absolute_error')

    grid_cv_lasso.fit(x_train, y_train)

    y_pred = grid_cv_lasso.best_estimator_.predict(x_test)
    print('class:', i)
    print(data_x)
    print('mae:', mae(y_test, y_pred))
    print('max abs err:', max_error(y_test, y_pred))
    print('***************************')
    predictions = []
    for i, row in enumerate(y_test):
        predictions.append({
            'elem': data.loc[y_test.index[i]],
            'test': row,
            'pred': y_pred[i],
            #'mae': abs(y_test[i] - y_pred[i])
                           })
    top_err = sorted(predictions, key = lambda o: abs(o['test'] - o['pred']))
    top_err.reverse()

    for elem in (top_err[:20]):
        print('name:', elem['elem']['Shrt_Desc'])
        print('test:', elem['test'])
        print('pred:', elem['pred'])
        print('_______________')
# Out:
# class: 0
#       Protein_(g)  Lipid_Tot_(g)  Carbohydrt_(g)  Energ_Kcal
# 0           12.00           6.00           73.40         393
# 7            7.10           6.00           52.60         299
# 9           11.24           2.01           81.01         348
# 10          10.50          11.70           73.20         440
# 11           5.40          22.60           66.80         481
# ...           ...            ...             ...         ...
# 7738         6.09           8.69           72.12         263
# 7740         1.42           7.17           72.18         359
# 7741         3.90           9.50           81.00         423
# 7744         3.44           8.20           34.03         218
# 7746        12.23          12.63           32.11         291
#
# [1922 rows x 4 columns]
# mae: 13.832081295168857
# max abs err: 133.01245220251627
# ***************************
# name: OAT BRAN,RAW
# test: 246
# pred: 379.0124522025163
# _______________
# name: CEREALS RTE,KELLOGG,KELLOGG'S ALL-BRAN ORIGINAL
# test: 260
# pred: 377.49369012246
# _______________
# name: ALLSPICE,GROUND
# test: 263
# pred: 379.96285369668203
# _______________
# name: SPICES,BAY LEAF
# test: 313
# pred: 392.53435475458815
# _______________
# name: MARJORAM,DRIED
# test: 271
# pred: 343.3936843130766
# _______________
# name: SPICES,THYME,DRIED
# test: 276
# pred: 348.16154268328677
# _______________
# name: CEREALS RTE,UNCLE SAM CRL
# test: 346
# pred: 412.49050142057615
# _______________
# name: CEREALS RTE,GENERAL MILLS,FIBER ONE,CARAMEL DELIGHT
# test: 344
# pred: 393.6028008393586
# _______________
# name: CEREALS RTE,GENERAL MILLS,FIBER ONE,FRSTD SHREDDED WHEAT
# test: 321
# pred: 362.865905756559
# _______________
# name: TOMATOES,SUN-DRIED
# test: 258
# pred: 295.09476828803207
# _______________
# name: CEREALS RTE,KELLOGG,KELLOGG'S RAISIN BRAN
# test: 318
# pred: 353.05614212129785
# _______________
# name: SEAWEED,AGAR,DRIED
# test: 306
# pred: 340.8817392786271
# _______________
# name: CEREALS RTE,KELLOGG,KELLOGG'S MINI-WHEATS,UNFROSTED BITE SZE
# test: 342
# pred: 372.9129357788115
# _______________
# name: KELLOGG'S,EGGO,FIBERPLUS WAFFLES,BTTRMLK
# test: 227
# pred: 255.80631946814196
# _______________
# name: BACON BITS,MEATLESS
# test: 476
# pred: 447.28094592221726
# _______________
# name: MURRAY,SUGAR FREE,SHORTBREAD COOKIES
# test: 431
# pred: 459.1823471185526
# _______________
# name: BLUEBERRIES,DRIED,SWTND
# test: 317
# pred: 344.82568082718865
# _______________
# name: MURRAY,SUGAR FREE,CHOC CREME SNDWCH COOKIES
# test: 465
# pred: 492.74537136996383
# _______________
# name: MACADAMIA NUTS,DRY RSTD,W/SALT
# test: 716
# pred: 743.5188043163707
# _______________
# name: PERSIMMONS,JAPANESE,DRIED
# test: 274
# pred: 300.40037409737727
# _______________
# class: 1
#       Protein_(g)  Lipid_Tot_(g)  Carbohydrt_(g)  Energ_Kcal
# 1            2.52           0.62            4.62          28
# 25           0.66           3.61            4.26          52
# 27           2.56           7.47           22.22         166
# 29           2.04           1.43            7.76          52
# 30           0.79           0.28            6.57          30
# ...           ...            ...             ...         ...
# 7745         0.10           0.10           26.10         100
# 7748         1.90           0.40            5.63          28
# 7749         0.98           0.00            9.18          39
# 7753         5.06           7.59           11.27         132
# 7754         0.28           0.12           19.91          74
#
# [1786 rows x 4 columns]
# mae: 3.6628225338674603
# max abs err: 61.78286859769656
# ***************************
# name: MCDONALD'S,NEWMAN'S OWN LOFAT BALSAMIC VINAIGRETTE
# test: 86
# pred: 147.78286859769656
# _______________
# name: KASHI,ORIGINAL WAFFLE
# test: 197
# pred: 224.9425602631028
# _______________
# name: ALCOHOLIC BEV,BEER,LT,BUDWEISER SEL
# test: 28
# pred: 3.609546854334546
# _______________
# name: AVOCADOS,RAW,ALL COMM VAR
# test: 160
# pred: 174.1937211930184
# _______________
# name: GRAPE LEAVES,RAW
# test: 93
# pred: 106.65404692288075
# _______________
# name: ICE CREAMS,BREYERS,98% FAT FREE CHOC
# test: 136
# pred: 148.83894660607007
# _______________
# name: SOYBEANS,MATURE CKD,BLD,WO/SALT
# test: 173
# pred: 185.75165149017965
# _______________
# name: CORN,SWT,YEL,FRZ,KRNLS ON COB,UNPREP
# test: 98
# pred: 108.44758402347858
# _______________
# name: SPAGHETTI,CKD,ENR,W/ SALT
# test: 157
# pred: 146.63897685712863
# _______________
# name: MACARONI,CKD,UNENR
# test: 158
# pred: 147.65764542648668
# _______________
# name: AVOCADOS,RAW,FLORIDA
# test: 120
# pred: 130.23220661340986
# _______________
# name: RICE,WHITE,LONG-GRAIN,PARBLD,UNENR,CKD
# test: 123
# pred: 112.82899369952705
# _______________
# name: CORN,SWT,YEL,FRZ,KRNLS ON COB,CKD,BLD,DRND,W/SALT
# test: 94
# pred: 102.98734365172528
# _______________
# name: CORN,SWT,WHITE,FRZ,KRNLS CUT OFF COB,UNPREP
# test: 88
# pred: 96.86652434301483
# _______________
# name: ROSE HIPS,WILD (NORTHERN PLAINS INDIANS)
# test: 162
# pred: 153.23670382090387
# _______________
# name: PICKLES,CUCUMBER,SWT,LO NA (INCLUDES BREAD & BUTTER PICKLES)
# test: 122
# pred: 130.64962687632254
# _______________
# name: MUNG BNS,MATURE SEEDS,SPROUTED,CKD,STIR-FRIED
# test: 50
# pred: 58.58506159544094
# _______________
# name: CORN,SWT,WHITE,FRZ,KRNLS CUT OFF COB,BLD,DRND,W/SALT
# test: 80
# pred: 88.25457702578497
# _______________
# name: RICE,WHITE,GLUTINOUS,CKD
# test: 97
# pred: 88.90933582763998
# _______________
# name: CAMPBELL'S RED & WHITE,SPLIT PEA W/ HAM & BACON SOUP,COND
# test: 141
# pred: 133.471547914525
# _______________
# class: 2
#       Protein_(g)  Lipid_Tot_(g)  Carbohydrt_(g)  Energ_Kcal
# 6            6.50          10.80           40.70         285
# 17          28.94           9.42            2.90         212
# 23           8.15           8.00            5.15         116
# 24           0.07           0.00            1.94          81
# 38          14.73           5.00           18.88         179
# ...           ...            ...             ...         ...
# 7720         0.19           0.00            0.00           1
# 7721         3.99           4.00           17.60         122
# 7723         2.80           2.90           18.92         113
# 7743        22.30          14.22            5.39         239
# 7750         1.38           3.50            7.18          63
#
# [1422 rows x 4 columns]
# mae: 7.826575478695847
# max abs err: 220.0664288188825
# ***************************
# name: VANILLA EXTRACT,IMITN,ALCOHOL
# test: 237
# pred: 16.933571181117486
# _______________
# name: ALCOHOLIC BEV,WINE,TABLE,RED,MOUVEDRE
# test: 88
# pred: 17.87780972781759
# _______________
# name: ALCOHOLIC BEV,WINE,TABLE,RED
# test: 85
# pred: 17.764799500373755
# _______________
# name: ALCOHOLIC BEV,WINE,TABLE,WHITE,FUME BLANC
# test: 82
# pred: 16.484016922677007
# _______________
# name: ALCOHOLIC BEV,WINE,TABLE,WHITE,SAUVIGNON BLANC
# test: 81
# pred: 15.65527525475558
# _______________
# name: ALCOHOLIC BEV,WINE,TABLE,RED,GAMAY
# test: 78
# pred: 16.898387756637717
# _______________
# name: COCONUT MEAT,DRIED (DESICCATED),CRMD
# test: 684
# pred: 717.1357174963641
# _______________
# name: PEACHES,DEHYD (LOW-MOISTURE),SULFURED,UNCKD
# test: 325
# pred: 349.0910869596462
# _______________
# name: BEECHNUTS,DRIED
# test: 576
# pred: 597.895516014623
# _______________
# name: SOY MEAL,DEFATTED,RAW,CRUDE PROT BASIS (N X 6.25)
# test: 337
# pred: 355.3402394914745
# _______________
# name: TEMPEH,CKD
# test: 196
# pred: 213.78992619486948
# _______________
# name: BEANS,KIDNEY,MATURE SEEDS,SPROUTED,CKD,BLD,DRND,WO/SALT
# test: 33
# pred: 49.338966274391616
# _______________
# name: PORK,CURED,BACON,CKD,BRLD,PAN-FRIED OR RSTD,RED NA
# test: 541
# pred: 524.7746617697047
# _______________
# name: LEMON GRASS (CITRONELLA),RAW
# test: 99
# pred: 114.39687344359633
# _______________
# name: COWPEAS,LEAFY TIPS,CKD,BLD,DRND,WO/SALT
# test: 22
# pred: 37.26052349701536
# _______________
# name: COWPEAS,LEAFY TIPS,RAW
# test: 29
# pred: 43.971556738734066
# _______________
# name: FAST FOODS,POTATO,BKD&TOPPED W/CHS SAU&BACON
# test: 163
# pred: 177.2878849429995
# _______________
# name: VINEGAR,BALSAMIC
# test: 88
# pred: 73.7194116872872
# _______________
# name: PRUNES,DEHYD (LOW-MOISTURE),STWD
# test: 113
# pred: 126.43857635269816
# _______________
# name: WHEAT FLR,WHITE,TORTILLA MIX,ENR
# test: 405
# pred: 391.69345380511186
# _______________
# class: 3
#       Protein_(g)  Lipid_Tot_(g)  Carbohydrt_(g)  Energ_Kcal
# 2           24.06          11.09            0.00         196
# 3           20.43          21.35            0.00         280
# 5           21.04           6.88            0.00         146
# 8           28.10           9.70            0.00         208
# 12          30.19           1.90            0.00         146
# ...           ...            ...             ...         ...
# 7742        20.88          23.39            0.03         294
# 7747        31.94          13.60            0.00         250
# 7751        17.54           4.93            0.00         119
# 7752        20.59          15.04            0.00         224
# 7755        24.40           0.49            0.00         109
#
# [2450 rows x 4 columns]
# mae: 4.134522662409691
# max abs err: 25.445944319040223
# ***************************
# name: WHELK,UNSPEC,CKD,MOIST HEAT
# test: 275
# pred: 249.55405568095978
# _______________
# name: COD,ATLANTIC,DRIED&SALTED
# test: 290
# pred: 268.15301313911436
# _______________
# name: MCDONALD'S,CREAMY RANCH SAU
# test: 468
# pred: 484.6198775098936
# _______________
# name: FISH OIL,COD LIVER
# test: 902
# pred: 888.3995764092896
# _______________
# name: FAT,BEEF TALLOW
# test: 902
# pred: 888.3995764092896
# _______________
# name: FAT,GOOSE
# test: 900
# pred: 886.6507265630316
# _______________
# name: PORK,FRSH,VAR MEATS&BY-PRODUCTS,LEAF FAT,RAW
# test: 857
# pred: 843.8737514900577
# _______________
# name: MEAT DRIPPINGS (LARD,BF TALLOW,MUTTON TALLOW)
# test: 889
# pred: 876.0701849931719
# _______________
# name: SHORTENING INDUSTRIAL,LARD&VEG OIL
# test: 900
# pred: 888.3995764092896
# _______________
# name: OIL,INDUSTRIAL,SOY,LO LINOLENIC
# test: 900
# pred: 888.3995764092896
# _______________
# name: CREAM,FLUID,LT WHIPPING
# test: 292
# pred: 302.12549298275405
# _______________
# name: LAMB,DOM,SHLDR,ARM,LN,1/4"FAT,CHOIC,CKD,BRSD
# test: 279
# pred: 269.16901746930955
# _______________
# name: BUTTER,WITHOUT SALT
# test: 717
# pred: 726.5782024349421
# _______________
# name: BEEF,CHUCK,BLADE RST,LN&FAT,1/8"FAT,CHOIC,CKD,BRSD
# test: 359
# pred: 350.3402588581405
# _______________
# name: BEEF,CHUCK,ARM POT RST,LN&FAT,1/8"FAT,CHOIC,CKD,BRSD
# test: 309
# pred: 300.47812901860505
# _______________
# name: PRK,CRD,HAM W/ NAT JUCS,SPRL SLC,MEAT ONLY,BNLES,LN,HTD,RSTD
# test: 126
# pred: 134.44274364925838
# _______________
# name: CHICKEN,BROILERS OR FRYERS,WING,MEAT&SKN,CKD,FRIED,FLR
# test: 321
# pred: 312.6926917703976
# _______________
# name: PORK,CURED,HAM -- H2O ADDED,WHL,BNLESS,LN & FAT,UNHTD
# test: 121
# pred: 129.1200844295375
# _______________
# name: BEEF,RND,TOP RND,LN,0"FAT,CHOIC,CKD,BRSD
# test: 207
# pred: 198.92205573370575
# _______________
# name: BEEF,RND,BTTM RND,STEAK,LN,1/8" FAT,CHOIC,CKD,BRSD
# test: 228
# pred: 220.01767341536367
# _______________
# class: 4
#       Protein_(g)  Lipid_Tot_(g)  Carbohydrt_(g)  Energ_Kcal
# 4            0.00           0.00            0.04          18
# 40           0.10           0.00            0.34           2
# 229          1.20           0.20            3.84          18
# 253          0.33           0.20            2.26          11
# 326          0.95           0.18            3.31          16
# ...           ...            ...             ...         ...
# 7576         0.00           0.00            0.30           1
# 7617         0.50           0.30            2.41          12
# 7631         0.70           0.10            4.07          17
# 7728         1.14           0.36            2.69          15
# 7735         1.15           0.13            2.97          14
#
# [176 rows x 4 columns]
# mae: 4.755654983842904
# max abs err: 15.026845637583893
# ***************************
# name: TEA,HERB,CHAMOMILE,BREWED
# test: 1
# pred: 16.026845637583893
# _______________
# name: TEA,BLACK,BREWED,PREP W/ TAP H2O
# test: 1
# pred: 16.026845637583893
# _______________
# name: CLAM,MXD SP,CND,LIQ
# test: 2
# pred: 16.026845637583893
# _______________
# name: VEGETABLE & FRUIT JUC DRK,RED CAL,ADDED VIT C
# test: 4
# pred: 16.026845637583893
# _______________
# name: COFFEE SUB,CRL GRAIN BEV,PREP W/ H2O
# test: 6
# pred: 16.026845637583893
# _______________
# name: SOUP,CHICK BROTH,RTS
# test: 6
# pred: 16.026845637583893
# _______________
# name: BEVERAGES,PEPSICO QUAKER,GATORADE G2,LO CAL
# test: 8
# pred: 16.026845637583893
# _______________
# name: COFFEE,BREWED,ESPRESSO,REST-PREP
# test: 9
# pred: 16.026845637583893
# _______________
# name: WAXGOURD,(CHINESE PRESERVING MELON),CKD,BLD,DRND,W/SALT
# test: 11
# pred: 16.026845637583893
# _______________
# name: MELON,BANANA (NAVAJO)
# test: 21
# pred: 16.026845637583893
# _______________
# name: CAMPBELL'S RED & WHITE,BF BROTH,COND
# test: 12
# pred: 16.026845637583893
# _______________
# name: CABBAGE,CHINESE (PAK-CHOI),CKD,BLD,DRND,W/SALT
# test: 12
# pred: 16.026845637583893
# _______________
# name: NEW ZEALAND SPINACH,CKD,BLD,DRND,WO/SALT
# test: 12
# pred: 16.026845637583893
# _______________
# name: GELATIN DSSRT,DRY MIX,RED CAL,W/ ASPRT,PREP W/ H2O
# test: 20
# pred: 16.026845637583893
# _______________
# name: SQUASH,SMMR,CROOKNECK&STRAIGHTNECK,CKD,BLD,DRND,W/SALT
# test: 19
# pred: 16.026845637583893
# _______________
# name: CABBAGE,CHINESE (PE-TSAI),CKD,BLD,DRND,W/SALT
# test: 14
# pred: 16.026845637583893
# _______________
# name: PEPPERS,SWT,RED,CND,SOL&LIQUIDS
# test: 18
# pred: 16.026845637583893
# _______________
# name: BEANS,SNAP,YEL,CND,NO SALT,SOL&LIQUIDS
# test: 15
# pred: 16.026845637583893
# _______________
# name: GOURD,WHITE-FLOWERED (CALABASH),CKD,BLD,DRND,WO/SALT
# test: 15
# pred: 16.026845637583893
# _______________
# name: SQUASH,SMMR,ZUCCHINI,INCL SKN,RAW
# test: 17
# pred: 16.026845637583893
# _______________
# C:\Users\taras\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
data[data['label'] == 2]
# Out:
#                                               Shrt_Desc  Water_(g)  \
# 6     MUFFINS,BLUEBERRY,PREP FROM RECIPE,MADE W/LOFA...      39.50
# 17    POPEYES,FRIED CHICK,MILD,WING,MEAT ONLY,SKN & ...      55.85
# 23       TOFU,SALTED&FERMENTED (FUYU),PREP W/CA SULFATE      70.01
# 24           ALCOHOLIC BEV,WINE,TABLE,WHITE,PINOT BLANC      87.14
# 38                  WENDY'S,ULTIMATE CHICK GRILL SNDWCH      59.67
# ...                                                 ...        ...
# 7720          BEVERAGES,GRN TEA,SALADA BREWED FROM BAGS      99.95
# 7721              EGG CUSTARDS,DRY MIX,PREP W/ WHL MILK      73.45
# 7723      PUDDINGS,VANILLA,DRY MIX,REG,PREP W/ WHL MILK      74.49
# 7743  KFC,FRIED CHICK,ORIGINAL RECIPE,DRUMSTK,MEAT &...      55.60
# 7750  INF FORMULA, MEAD JOHNSON, ENFAMIL, LACTOFREE,...      88.35
#
#       Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 6            285         6.50          10.80     2.50           40.70
# 17           212        28.94           9.42     2.89            2.90
# 23           116         8.15           8.00     8.69            5.15
# 24            81         0.07           0.00     0.24            1.94
# 38           179        14.73           5.00     1.72           18.88
# ...          ...          ...            ...      ...             ...
# 7720           1         0.19           0.00     0.00            0.00
# 7721         122         3.99           4.00     0.97           17.60
# 7723         113         2.80           2.90     0.90           18.92
# 7743         239        22.30          14.22     2.49            5.39
# 7750          63         1.38           3.50     0.33            7.18
#
#       Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  ...  Vit_D_µg  Vit_D_IU  \
# 6              NaN            NaN         189.0  ...       NaN       NaN
# 17             NaN            NaN          38.0  ...       NaN       NaN
# 23             NaN            NaN        1229.0  ...       0.0       0.0
# 24             NaN            NaN           NaN  ...       NaN       NaN
# 38             1.1            NaN          25.0  ...       NaN       NaN
# ...            ...            ...           ...  ...       ...       ...
# 7720           NaN           0.00           1.0  ...       NaN       NaN
# 7721           0.0           4.82         139.0  ...       1.2      47.0
# 7723           0.1          17.09          99.0  ...       1.1      45.0
# 7743           NaN            NaN          29.0  ...       NaN       NaN
# 7750           0.0           7.18          53.0  ...       1.0      40.0
#
#       Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)  \
# 6            NaN       2.030        2.596        5.388            37.0
# 17           NaN       3.079        4.024        1.391           156.0
# 23           NaN       1.157        1.767        4.516             0.0
# 24           NaN         NaN          NaN          NaN             NaN
# 38           8.9       1.030        1.460        1.810            40.0
# ...          ...         ...          ...          ...             ...
# 7720         NaN         NaN          NaN          NaN             NaN
# 7721         0.2       2.032        1.127        0.312            51.0
# 7723         0.2       1.643        0.714        0.197             9.0
# 7743         NaN       3.240        5.115        4.290           117.0
# 7750         5.2       1.495        1.291        0.689             1.0
#
#       Refuse_Pct  label                                              probs
# 6            0.0      2  [0.06486954540014267, 0.3204026222229004, 0.41...
# 17          72.0      2  [0.06486954540014267, 0.3204026222229004, 0.41...
# 23           0.0      2  [0.06486954540014267, 0.3204026222229004, 0.41...
# 24           0.0      2  [0.06486954540014267, 0.3204026222229004, 0.41...
# 38           0.0      2  [0.07032429426908493, 0.12766174972057343, 0.6...
# ...          ...    ...                                                ...
# 7720         0.0      2  [0.06486954540014267, 0.3204026222229004, 0.41...
# 7721         0.0      2  [0.0033619224559515715, 0.25385621190071106, 0...
# 7723         0.0      2  [0.00186530954670161, 0.3621945083141327, 0.61...
# 7743        24.0      2  [0.06486954540014267, 0.3204026222229004, 0.41...
# 7750         0.0      2  [0.00043408293277025223, 0.33087751269340515, ...
#
# [1422 rows x 50 columns]
