# %% [markdown]
# # Препроцессинг

# %%
import pandas as pd
import seaborn as sns
import matplotlib
from scipy import stats
from scipy.stats import norm, skew #for some statistics

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %matplotlib inline

# %%
df = pd.read_excel("data/train.xlsx", index_col=0)
df
# Out:
#                                                     Water_(g)  Energ_Kcal  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                       4.70         393
# HEARTS OF PALM,CANNED                                   90.20          28
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...      63.89         196
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                 54.73         280
# VINEGAR,DISTILLED                                       94.78          18
# ...                                                       ...         ...
# DRUM,FRESHWATER,RAW                                     77.33         119
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW            63.95         224
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...      74.00         132
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                   79.36          74
# TUNA,FRESH,YELLOWFIN,RAW                                74.03         109
#
#                                                     Protein_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                        12.00
# HEARTS OF PALM,CANNED                                      2.52
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...        24.06
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                   20.43
# VINEGAR,DISTILLED                                          0.00
# ...                                                         ...
# DRUM,FRESHWATER,RAW                                       17.54
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW              20.59
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...         5.06
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                      0.28
# TUNA,FRESH,YELLOWFIN,RAW                                  24.40
#
#                                                     Lipid_Tot_(g)  Ash_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                           6.00     3.90
# HEARTS OF PALM,CANNED                                        0.62     2.04
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...          11.09     1.56
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                     21.35     3.51
# VINEGAR,DISTILLED                                            0.00     0.02
# ...                                                           ...      ...
# DRUM,FRESHWATER,RAW                                          4.93     1.08
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                15.04     0.87
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...           7.59     2.09
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        0.12     0.33
# TUNA,FRESH,YELLOWFIN,RAW                                     0.49     1.64
#
#                                                     Carbohydrt_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                           73.40
# HEARTS OF PALM,CANNED                                         4.62
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...            0.00
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                       0.00
# VINEGAR,DISTILLED                                             0.04
# ...                                                            ...
# DRUM,FRESHWATER,RAW                                           0.00
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                  0.00
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...           11.27
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        19.91
# TUNA,FRESH,YELLOWFIN,RAW                                      0.00
#
#                                                     Fiber_TD_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                           5.2
# HEARTS OF PALM,CANNED                                        2.4
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...           0.0
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                      0.0
# VINEGAR,DISTILLED                                            0.0
# ...                                                          ...
# DRUM,FRESHWATER,RAW                                          0.0
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                 0.0
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...           1.8
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        2.6
# TUNA,FRESH,YELLOWFIN,RAW                                     0.0
#
#                                                     Sugar_Tot_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                          13.75
# HEARTS OF PALM,CANNED                                         NaN
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...           0.00
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                      0.00
# VINEGAR,DISTILLED                                            0.04
# ...                                                           ...
# DRUM,FRESHWATER,RAW                                           NaN
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                 0.00
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...            NaN
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                         NaN
# TUNA,FRESH,YELLOWFIN,RAW                                     0.00
#
#                                                     Calcium_(mg)  Iron_(mg)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                         651.0      47.50
# HEARTS OF PALM,CANNED                                       58.0       3.13
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...          13.0       0.97
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                     10.0       0.95
# VINEGAR,DISTILLED                                            6.0       0.03
# ...                                                          ...        ...
# DRUM,FRESHWATER,RAW                                         60.0       0.90
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                23.0       1.47
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...         119.0       0.64
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        4.0       0.43
# TUNA,FRESH,YELLOWFIN,RAW                                     4.0       0.77
#
#                                                     ...  Vit_K_(µg)  \
# Shrt_Desc                                           ...
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                  ...         3.0
# HEARTS OF PALM,CANNED                               ...         NaN
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...  ...         0.0
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD             ...         0.0
# VINEGAR,DISTILLED                                   ...         0.0
# ...                                                 ...         ...
# DRUM,FRESHWATER,RAW                                 ...         NaN
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW        ...         1.6
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...  ...         NaN
# APPLES,DEHYD (LO MOIST),SULFURED,STWD               ...         NaN
# TUNA,FRESH,YELLOWFIN,RAW                            ...         0.1
#
#                                                     FA_Sat_(g)  FA_Mono_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                       1.267        1.429
# HEARTS OF PALM,CANNED                                    0.130        0.103
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...       2.866        4.878
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                  7.670       10.140
# VINEGAR,DISTILLED                                        0.000        0.000
# ...                                                        ...          ...
# DRUM,FRESHWATER,RAW                                      1.119        2.190
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW             6.067        6.438
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...       3.530        2.587
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                    0.020        0.005
# TUNA,FRESH,YELLOWFIN,RAW                                 0.172        0.116
#
#                                                     FA_Poly_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                        2.186
# HEARTS OF PALM,CANNED                                     0.202
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...        1.673
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                   2.320
# VINEGAR,DISTILLED                                         0.000
# ...                                                         ...
# DRUM,FRESHWATER,RAW                                       1.154
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW              0.572
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...        1.076
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                     0.036
# TUNA,FRESH,YELLOWFIN,RAW                                  0.147
#
#                                                     Cholestrl_(mg)  GmWt_1  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                             0.0     2.0
# HEARTS OF PALM,CANNED                                          0.0   146.0
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...           130.0    89.0
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                       58.0   140.0
# VINEGAR,DISTILLED                                              0.0    14.0
# ...                                                            ...     ...
# DRUM,FRESHWATER,RAW                                           64.0    85.0
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                  80.0    85.0
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...            15.0   245.0
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                          0.0   193.0
# TUNA,FRESH,YELLOWFIN,RAW                                      39.0    28.0
#
#                                                         GmWt_Desc1  GmWt_2  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                          1 tbsp    15.0
# HEARTS OF PALM,CANNED                                        1 cup    33.0
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...         1 thigh    85.0
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                      1 cup    85.0
# VINEGAR,DISTILLED                                           1 tbsp   238.0
# ...                                                            ...     ...
# DRUM,FRESHWATER,RAW                                           3 oz   198.0
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                  3 oz     NaN
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...           1 cup     NaN
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        1 cup     NaN
# TUNA,FRESH,YELLOWFIN,RAW                            1 oz, boneless    16.0
#
#                                                                 GmWt_Desc2  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                                   .5 oz
# HEARTS OF PALM,CANNED                                              1 piece
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...      1 serving,  (3 oz)
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                               3 oz
# VINEGAR,DISTILLED                                                    1 cup
# ...                                                                    ...
# DRUM,FRESHWATER,RAW                                               1 fillet
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                           NaN
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...                     NaN
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                                  NaN
# TUNA,FRESH,YELLOWFIN,RAW                            1 cubic inch, boneless
#
#                                                     Refuse_Pct
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                         0.0
# HEARTS OF PALM,CANNED                                      0.0
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...        29.0
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                   27.0
# VINEGAR,DISTILLED                                          0.0
# ...                                                        ...
# DRUM,FRESHWATER,RAW                                        0.0
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW               9.0
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...         0.0
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                      0.0
# TUNA,FRESH,YELLOWFIN,RAW                                   0.0
#
# [7756 rows x 51 columns]

# %%
print(df.shape)
# Out:
# (7756, 51)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7756 entries, BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY to TUNA,FRESH,YELLOWFIN,RAW
# Data columns (total 51 columns):
# Water_(g)            7751 non-null float64
# Energ_Kcal           7756 non-null int64
# Protein_(g)          7756 non-null float64
# Lipid_Tot_(g)        7756 non-null float64
# Ash_(g)              7461 non-null float64
# Carbohydrt_(g)       7756 non-null float64
# Fiber_TD_(g)         7168 non-null float64
# Sugar_Tot_(g)        6013 non-null float64
# Calcium_(mg)         7443 non-null float64
# Iron_(mg)            7630 non-null float64
# Magnesium_(mg)       7139 non-null float64
# Phosphorus_(mg)      7234 non-null float64
# Potassium_(mg)       7390 non-null float64
# Sodium_(mg)          7681 non-null float64
# Zinc_(mg)            7123 non-null float64
# Copper_mg)           6630 non-null float64
# Manganese_(mg)       5828 non-null float64
# Selenium_(µg)        6175 non-null float64
# Vit_C_(mg)           7053 non-null float64
# Thiamin_(mg)         7138 non-null float64
# Riboflavin_(mg)      7156 non-null float64
# Niacin_(mg)          7137 non-null float64
# Panto_Acid_mg)       5825 non-null float64
# Vit_B6_(mg)          6909 non-null float64
# Folate_Tot_(µg)      6639 non-null float64
# Folic_Acid_(µg)      5975 non-null float64
# Food_Folate_(µg)     6178 non-null float64
# Folate_DFE_(µg)      5958 non-null float64
# Choline_Tot_ (mg)    4095 non-null float64
# Vit_B12_(µg)         6685 non-null float64
# Vit_A_IU             7145 non-null float64
# Vit_A_RAE            6387 non-null float64
# Retinol_(µg)         6134 non-null float64
# Alpha_Carot_(µg)     4732 non-null float64
# Beta_Carot_(µg)      4815 non-null float64
# Beta_Crypt_(µg)      4724 non-null float64
# Lycopene_(µg)        4701 non-null float64
# Lut+Zea_ (µg)        4679 non-null float64
# Vit_E_(mg)           5060 non-null float64
# Vit_D_µg             4789 non-null float64
# Vit_D_IU             4790 non-null float64
# Vit_K_(µg)           4475 non-null float64
# FA_Sat_(g)           7444 non-null float64
# FA_Mono_(g)          7149 non-null float64
# FA_Poly_(g)          7157 non-null float64
# Cholestrl_(mg)       7426 non-null float64
# GmWt_1               7537 non-null float64
# GmWt_Desc1           7538 non-null object
# GmWt_2               4317 non-null float64
# GmWt_Desc2           4317 non-null object
# Refuse_Pct           7723 non-null float64
# dtypes: float64(48), int64(1), object(2)
# memory usage: 3.1+ MB

# %%
#data.drop(columns = ['GmWt_1','GmWt_Desc1','GmWt_2','GmWt_Desc2','Sugar_Tot_(g)', 'Thiamin_(mg)','Phosphorus_(mg)'], inplace = True, axis=0)
features_list = ['Energ_Kcal', 'Water_(g)','Protein_(g)','Lipid_Tot_(g)','Carbohydrt_(g)', 'Refuse_Pct']
data = df[features_list]
data.shape
# Out:
# (7756, 6)

# %%
label = 'Energ_Kcal'
buf = set(list(data.columns))
buf.remove(label)
real_vars = buf

# %%
sns.distplot(data[label] , fit=norm);

(mu, sigma) = norm.fit(data[label])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('label distribution')

fig = plt.figure()
res = stats.probplot(data[label], plot=plt)
plt.show()
# Out:
#  mu = 225.89 and sigma = 169.84

# %%
fig, ax = plt.subplots(figsize=(20,12))
sns_heatmap = sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
data.fillna(0, inplace = True)
data[real_vars].hist(figsize=(20, 20));
# Out:
# C:\Users\taras\Anaconda3\lib\site-packages\pandas\core\frame.py:4259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %%
plt.figure(figsize=(20,20))
corr = data.corr() 
sns.heatmap(corr, annot=True, square=True, fmt=".1f", linewidths=0.1, cmap="RdBu");

# %%
remove_list = []
for i,c in enumerate(corr['Energ_Kcal']):
    if((abs(c) < 0.15) and (not(corr.index[i] in ['Refuse_Pct', 'Protein_(g)']))):
        remove_list.append(corr.index[i])
remove_list
# Out:
# []

# %%
data.drop(columns=remove_list, inplace=True, axis=0)
# Out:
# C:\Users\taras\Anaconda3\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
plt.figure(figsize=(20,18))
corr = data.corr() 
sns.heatmap(corr, annot=True, square=True, fmt=".1f", linewidths=0.1, cmap="RdBu");

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))

for i, feature in enumerate((list(set(real_vars) - set(remove_list))) ):
    data.plot(feature, label, subplots=True, kind="scatter", ax=axes[i // 5, i % 4])

# %%
y = data[label]
x = data.drop(columns = [label])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=0)

# %%
# from sklearn.linear_model import ElasticNet
# model = ElasticNet(random_state=0)
# param_grid = {
#     'alpha': [0.001, 0.01, 0.05, 0.1, 0.5, 0.8, 1, 5, 10, 20,50,100],
#     'l1_ratio':[0,0.001, 0.01, 0.05, 0.1, 0.5, 0.8, 1]
# }
# grid_cv_lasso = GridSearchCV(model, param_grid, cv = 5, scoring='neg_mean_absolute_error')

# grid_cv_lasso.fit(x_train, y_train)

# %%
from sklearn.linear_model import Lasso
model = Lasso(random_state=0, max_iter= 10000)
param_grid = {
    'alpha': [0.0001, 0.001, 0.01, 0.05, 0.1, 0.5, 0.8, 1, 5, 10, 20,50,100],
}
grid_cv_lasso = GridSearchCV(model, param_grid, cv = 5, scoring='neg_mean_absolute_error')

grid_cv_lasso.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=10000, normalize=False, positive=False,
#                              precompute=False, random_state=0,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.05, 0.1, 0.5, 0.8, 1,
#                                    5, 10, 20, 50, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_absolute_error', verbose=0)

# %%
print('Лучшее значение параметра:', grid_cv_lasso.best_params_)
print('Лучшее качество:', grid_cv_lasso.best_score_)
# Out:
# Лучшее значение параметра: {'alpha': 0.0001}
# Лучшее качество: -8.047309043925544

# %%
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import max_error
y_pred = grid_cv_lasso.best_estimator_.predict(x_test)
print(mae(y_test, y_pred))
print(max_error(y_test, y_pred))
# Out:
# 7.207387411639061
# 141.3804488702051

# %%
predictions = []
for i, row in enumerate(y_test):
    predictions.append({
        'elem': data.loc[y_test.index[i]],
        'test': row,
        'pred': y_pred[i],
        'mae': abs(y_test[i] - y_pred[i])
                       })

# %%
top_err = sorted(predictions, key = lambda o: o['mae'])
top_err.reverse()

top_err[:10]
# Out:
# [{'elem': Energ_Kcal        222.00
#   Water_(g)           3.58
#   Protein_(g)         4.62
#   Lipid_Tot_(g)       0.65
#   Carbohydrt_(g)     88.88
#   Refuse_Pct          0.00
#   Name: CAROB FLOUR, dtype: float64,
#   'test': 222,
#   'pred': 363.3804488702051,
#   'mae': 141.3804488702051},
#  {'elem': Energ_Kcal        218.00
#   Water_(g)           1.84
#   Protein_(g)         0.45
#   Lipid_Tot_(g)       0.04
#   Carbohydrt_(g)     87.38
#   Refuse_Pct          0.00
#   Name: FRUIT-FLAVORED DRK,DRY PDR MIX,LO CAL,W/ ASPRT, dtype: float64,
#   'test': 218,
#   'pred': 344.18600962796677,
#   'mae': 126.18600962796677},
#  {'elem': Energ_Kcal        248.00
#   Water_(g)           2.20
#   Protein_(g)         4.80
#   Lipid_Tot_(g)       2.59
#   Carbohydrt_(g)     85.19
#   Refuse_Pct          0.00
#   Name: CEREALS RTE,GENERAL MILLS,FIBER ONE 80 CAL,HONEY SQUARES, dtype: float64,
#   'test': 248,
#   'pred': 370.4158940787002,
#   'mae': 122.4158940787002},
#  {'elem': Energ_Kcal        274.00
#   Water_(g)           9.87
#   Protein_(g)         5.97
#   Lipid_Tot_(g)      13.00
#   Carbohydrt_(g)     65.53
#   Refuse_Pct          0.00
#   Name: CLOVES,GROUND, dtype: float64,
#   'test': 274,
#   'pred': 393.4171004481572,
#   'mae': 119.41710044815721},
#  {'elem': Energ_Kcal        253.00
#   Water_(g)           2.20
#   Protein_(g)         3.29
#   Lipid_Tot_(g)       2.90
#   Carbohydrt_(g)     84.00
#   Refuse_Pct          0.00
#   Name: CEREALS RTE,GENERAL MILLS,FIBER ONE 80 CAL,CHOC SQUARES, dtype: float64,
#   'test': 253,
#   'pred': 365.1804788219875,
#   'mae': 112.18047882198749},
#  {'elem': Energ_Kcal        290.00
#   Water_(g)           4.68
#   Protein_(g)        57.47
#   Lipid_Tot_(g)       7.72
#   Carbohydrt_(g)     23.90
#   Refuse_Pct          0.00
#   Name: SEAWEED,SPIRULINA,DRIED, dtype: float64,
#   'test': 290,
#   'pred': 395.3585762501347,
#   'mae': 105.35857625013472},
#  {'elem': Energ_Kcal        305.00
#   Water_(g)           7.70
#   Protein_(g)        15.98
#   Lipid_Tot_(g)      14.54
#   Carbohydrt_(g)     55.17
#   Refuse_Pct          0.00
#   Name: DILL SEED, dtype: float64,
#   'test': 305,
#   'pred': 408.8046364222974,
#   'mae': 103.80463642229739},
#  {'elem': Energ_Kcal        233.00
#   Water_(g)          10.35
#   Protein_(g)        22.98
#   Lipid_Tot_(g)       4.07
#   Carbohydrt_(g)     47.75
#   Refuse_Pct          0.00
#   Name: SPICES,BASIL,DRIED, dtype: float64,
#   'test': 233,
#   'pred': 324.9460998383587,
#   'mae': 91.94609983835869},
#  {'elem': Energ_Kcal        164.00
#   Water_(g)          69.15
#   Protein_(g)         0.10
#   Lipid_Tot_(g)       0.02
#   Carbohydrt_(g)     15.85
#   Refuse_Pct          0.00
#   Name: ALCOHOLIC BEV,WHISKEY SOUR,PREP W/ H2O,WHISKEY & PDR MIX, dtype: float64,
#   'test': 164,
#   'pred': 78.59381061464686,
#   'mae': 85.40618938535314},
#  {'elem': Energ_Kcal        327.0
#   Water_(g)          46.5
#   Protein_(g)         2.8
#   Lipid_Tot_(g)      15.7
#   Carbohydrt_(g)     20.9
#   Refuse_Pct          0.0
#   Name: ALCOHOLIC BEV,LIQUEUR,COFFEE W/CRM,34 PROOF, dtype: float64,
#   'test': 327,
#   'pred': 245.7672897162929,
#   'mae': 81.23271028370709}]

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Истинные значения')
plt.ylabel('Предсказанные значения')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

# %%
featureImportance = pd.DataFrame({"feature": x_test.columns,  "importance": grid_cv_lasso.best_estimator_.coef_})
featureImportance.set_index('feature', inplace=True)
featureImportance.sort_values(["importance"], ascending=False, inplace=True)
featureImportance.plot.bar()

# %%
from sklearn.ensemble import RandomForestRegressor

# Объявили лес из 10 деревьев 
rf = RandomForestRegressor(n_estimators=200, criterion='mae')

# Обучили лес 
rf.fit(x_train, y_train)

# Сделали по лесу прогнозы 
y_pred_forest = rf.predict(x_test)

# %%
mae(y_test, y_pred_forest)
# Out:
# 5.852532216494844

# %%
plt.scatter(y_test, y_pred_forest)
plt.xlabel('Истинные значения')
plt.ylabel('Предсказанные значения')
plt.axis('equal')
plt.axis('square')
plt.xlim([0,plt.xlim()[1]])
plt.ylim([0,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
