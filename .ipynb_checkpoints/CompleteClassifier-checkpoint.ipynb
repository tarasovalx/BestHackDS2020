# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_excel("data/clean_predictions.xlsx",  index_col = 0)
data

# %%
# Out:
#                                               Shrt_Desc  Water_(g)  \
# 0                    BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY       4.70
# 1                                 HEARTS OF PALM,CANNED      90.20
# 2     CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD...      63.89
# 3               PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD      54.73
# 4                                     VINEGAR,DISTILLED      94.78
# ...                                                 ...        ...
# 7751                                DRUM,FRESHWATER,RAW      77.33
# 7752       BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW      63.95
# 7753  POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE U...      74.00
# 7754              APPLES,DEHYD (LO MOIST),SULFURED,STWD      79.36
# 7755                           TUNA,FRESH,YELLOWFIN,RAW      74.03
#
#       Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0            393        12.00           6.00     3.90           73.40
# 1             28         2.52           0.62     2.04            4.62
# 2            196        24.06          11.09     1.56            0.00
# 3            280        20.43          21.35     3.51            0.00
# 4             18         0.00           0.00     0.02            0.04
# ...          ...          ...            ...      ...             ...
# 7751         119        17.54           4.93     1.08            0.00
# 7752         224        20.59          15.04     0.87            0.00
# 7753         132         5.06           7.59     2.09           11.27
# 7754          74         0.28           0.12     0.33           19.91
# 7755         109        24.40           0.49     1.64            0.00
#
#       Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  ...  Vit_D_µg  Vit_D_IU  \
# 0              5.2          13.75         651.0  ...       0.0       0.0
# 1              2.4            NaN          58.0  ...       0.0       0.0
# 2              0.0           0.00          13.0  ...       NaN       NaN
# 3              0.0           0.00          10.0  ...       0.7      29.0
# 4              0.0           0.04           6.0  ...       0.0       0.0
# ...            ...            ...           ...  ...       ...       ...
# 7751           0.0            NaN          60.0  ...       NaN       NaN
# 7752           0.0           0.00          23.0  ...       NaN       NaN
# 7753           1.8            NaN         119.0  ...       0.0       0.0
# 7754           2.6            NaN           4.0  ...       0.0       0.0
# 7755           0.0           0.00           4.0  ...       1.7      69.0
#
#       Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)  \
# 0            3.0       1.267        1.429        2.186             0.0
# 1            NaN       0.130        0.103        0.202             0.0
# 2            0.0       2.866        4.878        1.673           130.0
# 3            0.0       7.670       10.140        2.320            58.0
# 4            0.0       0.000        0.000        0.000             0.0
# ...          ...         ...          ...          ...             ...
# 7751         NaN       1.119        2.190        1.154            64.0
# 7752         1.6       6.067        6.438        0.572            80.0
# 7753         NaN       3.530        2.587        1.076            15.0
# 7754         NaN       0.020        0.005        0.036             0.0
# 7755         0.1       0.172        0.116        0.147            39.0
#
#       Refuse_Pct  label                                              probs
# 0            0.0      0  [0.9998394250869751, 3.4087479434674606e-05, 0...
# 1            0.0      1  [2.999854586960282e-08, 0.9994088411331177, 4....
# 2           29.0      3  [2.9562095733126625e-05, 7.411003025481477e-05...
# 3           27.0      3  [0.00026382150826975703, 0.0006710545276291668...
# 4            0.0      4  [1.605821307748556e-05, 0.028907138854265213, ...
# ...          ...    ...                                                ...
# 7751         0.0      3  [0.00042958883568644524, 0.0012661732034757733...
# 7752         9.0      3  [7.852991984691471e-05, 0.00026358681498095393...
# 7753         0.0      1  [0.000639920006506145, 0.8160973191261292, 0.1...
# 7754         0.0      1  [4.736647740699595e-10, 0.9999643564224243, 3....
# 7755         0.0      3  [9.45131469052285e-05, 0.0001476598990848288, ...
#
# [7672 rows x 50 columns]

# %%
data.isnull().sum(axis=1)
# Out:
# 0        2
# 1        9
# 2        2
# 3        0
# 4        0
#         ..
# 7751    11
# 7752     4
# 7753     8
# 7754     9
# 7755     0
# Length: 7672, dtype: int64

# %%
vars_ = ['Carbohydrt_(g)', 'Protein_(g)', 'Lipid_Tot_(g)', 'Fiber_TD_(g)', 'Water_(g)', 'Energ_Kcal','Ash_(g)']

# %%
data_x = data[vars_].fillna(0)
data_y = data['label']
data_x
# Out:
#       Carbohydrt_(g)  Protein_(g)  Lipid_Tot_(g)  Fiber_TD_(g)  Water_(g)  \
# 0              73.40        12.00           6.00           5.2       4.70
# 1               4.62         2.52           0.62           2.4      90.20
# 2               0.00        24.06          11.09           0.0      63.89
# 3               0.00        20.43          21.35           0.0      54.73
# 4               0.04         0.00           0.00           0.0      94.78
# ...              ...          ...            ...           ...        ...
# 7751            0.00        17.54           4.93           0.0      77.33
# 7752            0.00        20.59          15.04           0.0      63.95
# 7753           11.27         5.06           7.59           1.8      74.00
# 7754           19.91         0.28           0.12           2.6      79.36
# 7755            0.00        24.40           0.49           0.0      74.03
#
#       Energ_Kcal  Ash_(g)
# 0            393     3.90
# 1             28     2.04
# 2            196     1.56
# 3            280     3.51
# 4             18     0.02
# ...          ...      ...
# 7751         119     1.08
# 7752         224     0.87
# 7753         132     2.09
# 7754          74     0.33
# 7755         109     1.64
#
# [7672 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

data_x = scaler.fit_transform(data_x)

train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, test_size = 0.2)

train_y = train_y.to_numpy()
test_y = test_y.to_numpy()


test_y = to_categorical(test_y)
train_y = to_categorical(train_y)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, r2_score

clf = RandomForestClassifier(n_estimators=100, max_depth = 100, random_state=0, criterion = "entropy")
clf.fit(train_x, train_y)
y_pred = clf.predict(test_x)

print('Model accuracy score with 100 decision-trees : {0:0.4f}'. format(accuracy_score(test_y, y_pred)))
print('R2 score:  {0:0.4f}',  format(r2_score(test_y, y_pred)))
# Out:
# Model accuracy score with 100 decision-trees : 0.9459
# R2 score:  {0:0.4f} 0.8355180997321039

# %%
featureImportance = pd.DataFrame({"feature": data[vars_].columns,  "importance": clf.feature_importances_})
featureImportance.set_index('feature', inplace=True)
featureImportance.sort_values(["importance"], ascending=False, inplace=True)
featureImportance.plot.bar()

# %%
from keras.wrappers.scikit_learn import KerasRegressor
keras.backend.clear_session()

def learning_rate_reduction():
    return keras.callbacks.ReduceLROnPlateau(monitor='val_acc', 
                                            patience=4, 
                                            verbose=1, 
                                            factor=0.4, 
                                            min_lr=0.00002,
                                            mode='max')
def r2_keras(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

mcp_save = keras.callbacks.ModelCheckpoint('.mdl_wts.hdf5', save_best_only=True, monitor='val_acc', verbose = 1, mode='max')

def create_keras_model():
    model = keras.models.Sequential([
        keras.layers.BatchNormalization(input_shape = (len(vars_),)),
        keras.layers.Dense(1024, activation="relu"),
        keras.layers.BatchNormalization(),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.BatchNormalization(),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(64, activation="relu"),
        keras.layers.Dense(5, activation="softmax")])
    model.compile(optimizer = keras.optimizers.Adam(learning_rate=0.001),
                  loss = "categorical_crossentropy",
                  metrics = ['accuracy', r2_keras])
    return model

dnn_clf = KerasRegressor(build_fn=create_keras_model, verbose=0)

# %%
from sklearn.ensemble import StackingClassifier

estimators = [dnn_clf, clf]

ensemble = StackingClassifier(
   estimators=estimators, final_estimator = LogisticRegression()
)
ensemble.fit(train_x, train_y).score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-306-57198d9a72c4> in <module>
# ----> 1 from sklearn.ensemble import StackingClassifier
#       2
#       3 estimators = [dnn_clf, clf]
#       4
#       5 ensemble = StackingClassifier(
#
# ImportError: cannot import name 'StackingClassifier' from 'sklearn.ensemble' (C:\Users\taras\Anaconda3\lib\site-packages\sklearn\ensemble\__init__.py)

# %%
dnn_clf.fit(train_x,
          train_y,
          batch_size = 32,
          epochs = 20,
          validation_data=(test_x,test_y),
          callbacks=[learning_rate_reduction(), mcp_save])
dnn_clf.load_weights('.mdl_wts.hdf5')

dnn_clf.fit(train_x,
          train_y,
          batch_size = 64,
          epochs = 20,
          validation_data=(test_x,test_y),
          callbacks=[learning_rate_reduction(), mcp_save])
dnn_clf.load_weights('.mdl_wts.hdf5')

dnn_clf.fit(train_x,
          train_y,
          batch_size = 128,
          epochs = 20,
          validation_data=(test_x,test_y),
          callbacks=[learning_rate_reduction(), mcp_save])
dnn_clf.load_weights('.mdl_wts.hdf5')

dnn_clf.fit(train_x,
          train_y,
          batch_size = 256,
          epochs = 20,
          validation_data=(test_x,test_y),
          callbacks=[learning_rate_reduction(), mcp_save])
dnn_clf.load_weights('.mdl_wts.hdf5')
# Out:
# Train on 6137 samples, validate on 1535 samples
# Epoch 1/20
# 5984/6137 [============================>.] - ETA: 0s - loss: 0.4474 - acc: 0.8391 - r2_keras: 0.7063
# Epoch 00001: val_acc improved from -inf to 0.40065, saving model to .mdl_wts.hdf5
# 6137/6137 [==============================] - 2s 294us/sample - loss: 0.4453 - acc: 0.8393 - r2_keras: 0.7071 - val_loss: 1.3668 - val_acc: 0.4007 - val_r2_keras: 0.1083
# Epoch 2/20
# 6048/6137 [============================>.] - ETA: 0s - loss: 0.3645 - acc: 0.8603 - r2_keras: 0.7453
# Epoch 00002: val_acc improved from 0.40065 to 0.64495, saving model to .mdl_wts.hdf5
# 6137/6137 [==============================] - 1s 196us/sample - loss: 0.3631 - acc: 0.8612 - r2_keras: 0.7464 - val_loss: 0.7150 - val_acc: 0.6450 - val_r2_keras: 0.4765
# Epoch 3/20
# 5984/6137 [============================>.] - ETA: 0s - loss: 0.3396 - acc: 0.8695 - r2_keras: 0.7587
# Epoch 00003: val_acc improved from 0.64495 to 0.87427, saving model to .mdl_wts.hdf5
# 6137/6137 [==============================] - 1s 197us/sample - loss: 0.3368 - acc: 0.8708 - r2_keras: 0.7608 - val_loss: 0.3300 - val_acc: 0.8743 - val_r2_keras: 0.7792
# Epoch 4/20
# 5824/6137 [===========================>..] - ETA: 0s - loss: 0.3064 - acc: 0.8777 - r2_keras: 0.7782
# 6137/6137 [==============================] - 0s 31us/sample - loss: 0.1814 - acc: 0.9369 - r2_keras: 0.8750 - val_loss: 0.2104 - val_acc: 0.9349 - val_r2_keras: 0.8661
# Epoch 17/20
# 4352/6137 [====================>.........] - ETA: 0s - loss: 0.1875 - acc: 0.9343 - r2_keras: 0.8685
# Epoch 00017: val_acc did not improve from 0.93616
# 6137/6137 [==============================] - 0s 29us/sample - loss: 0.1787 - acc: 0.9379 - r2_keras: 0.8760 - val_loss: 0.2098 - val_acc: 0.9355 - val_r2_keras: 0.8667
# Epoch 18/20
# 4608/6137 [=====================>........] - ETA: 0s - loss: 0.1812 - acc: 0.9366 - r2_keras: 0.8742
# Epoch 00018: val_acc did not improve from 0.93616
# 6137/6137 [==============================] - 0s 29us/sample - loss: 0.1798 - acc: 0.9371 - r2_keras: 0.8751 - val_loss: 0.2095 - val_acc: 0.9355 - val_r2_keras: 0.8671
# Epoch 19/20
# 5120/6137 [========================>.....] - ETA: 0s - loss: 0.1757 - acc: 0.9383 - r2_keras: 0.8785
# Epoch 00019: val_acc did not improve from 0.93616
# 6137/6137 [==============================] - 0s 28us/sample - loss: 0.1791 - acc: 0.9369 - r2_keras: 0.8757 - val_loss: 0.2088 - val_acc: 0.9355 - val_r2_keras: 0.8678
# Epoch 20/20
# 4608/6137 [=====================>........] - ETA: 0s - loss: 0.1766 - acc: 0.9364 - r2_keras: 0.8769
# Epoch 00020: val_acc did not improve from 0.93616
# 6137/6137 [==============================] - 0s 32us/sample - loss: 0.1795 - acc: 0.9379 - r2_keras: 0.8755 - val_loss: 0.2086 - val_acc: 0.9355 - val_r2_keras: 0.8678

# %%
model.load_weights('.mdl_wts.hdf5')
model.evaluate(test_x, test_y, verbose=2)
# Out:
# 1535/1535 - 0s - loss: 0.2167 - acc: 0.9375
# [0.21670650121443435, 0.9374593]

# %%
data = pd.read_excel("data/train.xlsx", index_col = 0)
data.drop(columns=['GmWt_1', 'GmWt_Desc1', 'GmWt_2', 'GmWt_Desc2'], inplace = True)
np.mean(data.isnull().sum(axis=1))
data
# Out:
#                                                     Water_(g)  Energ_Kcal  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                       4.70         393
# HEARTS OF PALM,CANNED                                   90.20          28
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...      63.89         196
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                 54.73         280
# VINEGAR,DISTILLED                                       94.78          18
# ...                                                       ...         ...
# DRUM,FRESHWATER,RAW                                     77.33         119
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW            63.95         224
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...      74.00         132
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                   79.36          74
# TUNA,FRESH,YELLOWFIN,RAW                                74.03         109
#
#                                                     Protein_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                        12.00
# HEARTS OF PALM,CANNED                                      2.52
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...        24.06
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                   20.43
# VINEGAR,DISTILLED                                          0.00
# ...                                                         ...
# DRUM,FRESHWATER,RAW                                       17.54
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW              20.59
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...         5.06
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                      0.28
# TUNA,FRESH,YELLOWFIN,RAW                                  24.40
#
#                                                     Lipid_Tot_(g)  Ash_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                           6.00     3.90
# HEARTS OF PALM,CANNED                                        0.62     2.04
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...          11.09     1.56
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                     21.35     3.51
# VINEGAR,DISTILLED                                            0.00     0.02
# ...                                                           ...      ...
# DRUM,FRESHWATER,RAW                                          4.93     1.08
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                15.04     0.87
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...           7.59     2.09
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        0.12     0.33
# TUNA,FRESH,YELLOWFIN,RAW                                     0.49     1.64
#
#                                                     Carbohydrt_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                           73.40
# HEARTS OF PALM,CANNED                                         4.62
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...            0.00
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                       0.00
# VINEGAR,DISTILLED                                             0.04
# ...                                                            ...
# DRUM,FRESHWATER,RAW                                           0.00
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                  0.00
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...           11.27
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        19.91
# TUNA,FRESH,YELLOWFIN,RAW                                      0.00
#
#                                                     Fiber_TD_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                           5.2
# HEARTS OF PALM,CANNED                                        2.4
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...           0.0
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                      0.0
# VINEGAR,DISTILLED                                            0.0
# ...                                                          ...
# DRUM,FRESHWATER,RAW                                          0.0
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                 0.0
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...           1.8
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        2.6
# TUNA,FRESH,YELLOWFIN,RAW                                     0.0
#
#                                                     Sugar_Tot_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                          13.75
# HEARTS OF PALM,CANNED                                         NaN
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...           0.00
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                      0.00
# VINEGAR,DISTILLED                                            0.04
# ...                                                           ...
# DRUM,FRESHWATER,RAW                                           NaN
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                 0.00
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...            NaN
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                         NaN
# TUNA,FRESH,YELLOWFIN,RAW                                     0.00
#
#                                                     Calcium_(mg)  Iron_(mg)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                         651.0      47.50
# HEARTS OF PALM,CANNED                                       58.0       3.13
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...          13.0       0.97
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                     10.0       0.95
# VINEGAR,DISTILLED                                            6.0       0.03
# ...                                                          ...        ...
# DRUM,FRESHWATER,RAW                                         60.0       0.90
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                23.0       1.47
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...         119.0       0.64
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        4.0       0.43
# TUNA,FRESH,YELLOWFIN,RAW                                     4.0       0.77
#
#                                                     ...  Lut+Zea_ (µg)  \
# Shrt_Desc                                           ...
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                  ...          157.0
# HEARTS OF PALM,CANNED                               ...            NaN
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...  ...            0.0
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD             ...            0.0
# VINEGAR,DISTILLED                                   ...            0.0
# ...                                                 ...            ...
# DRUM,FRESHWATER,RAW                                 ...            NaN
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW        ...            0.0
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...  ...            NaN
# APPLES,DEHYD (LO MOIST),SULFURED,STWD               ...            NaN
# TUNA,FRESH,YELLOWFIN,RAW                            ...            0.0
#
#                                                     Vit_E_(mg)  Vit_D_µg  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                        5.00       0.0
# HEARTS OF PALM,CANNED                                      NaN       0.0
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...        0.25       NaN
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                   0.24       0.7
# VINEGAR,DISTILLED                                         0.00       0.0
# ...                                                        ...       ...
# DRUM,FRESHWATER,RAW                                        NaN       NaN
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW              0.38       NaN
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...         NaN       0.0
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                      NaN       0.0
# TUNA,FRESH,YELLOWFIN,RAW                                  0.24       1.7
#
#                                                     Vit_D_IU  Vit_K_(µg)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                       0.0         3.0
# HEARTS OF PALM,CANNED                                    0.0         NaN
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...       NaN         0.0
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                 29.0         0.0
# VINEGAR,DISTILLED                                        0.0         0.0
# ...                                                      ...         ...
# DRUM,FRESHWATER,RAW                                      NaN         NaN
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW             NaN         1.6
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...       0.0         NaN
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                    0.0         NaN
# TUNA,FRESH,YELLOWFIN,RAW                                69.0         0.1
#
#                                                     FA_Sat_(g)  FA_Mono_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                       1.267        1.429
# HEARTS OF PALM,CANNED                                    0.130        0.103
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...       2.866        4.878
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                  7.670       10.140
# VINEGAR,DISTILLED                                        0.000        0.000
# ...                                                        ...          ...
# DRUM,FRESHWATER,RAW                                      1.119        2.190
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW             6.067        6.438
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...       3.530        2.587
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                    0.020        0.005
# TUNA,FRESH,YELLOWFIN,RAW                                 0.172        0.116
#
#                                                     FA_Poly_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                        2.186
# HEARTS OF PALM,CANNED                                     0.202
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...        1.673
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                   2.320
# VINEGAR,DISTILLED                                         0.000
# ...                                                         ...
# DRUM,FRESHWATER,RAW                                       1.154
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW              0.572
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...        1.076
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                     0.036
# TUNA,FRESH,YELLOWFIN,RAW                                  0.147
#
#                                                     Cholestrl_(mg)  Refuse_Pct
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                             0.0         0.0
# HEARTS OF PALM,CANNED                                          0.0         0.0
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...           130.0        29.0
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                       58.0        27.0
# VINEGAR,DISTILLED                                              0.0         0.0
# ...                                                            ...         ...
# DRUM,FRESHWATER,RAW                                           64.0         0.0
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                  80.0         9.0
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...            15.0         0.0
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                          0.0         0.0
# TUNA,FRESH,YELLOWFIN,RAW                                      39.0         0.0
#
# [7756 rows x 47 columns]

# %%
data_x= data[vars_] .to_numpy()

# %%
raw_predictions = model.predict(data_x)
raw_predictions
# Out:
# array([[0.2108407 , 0.27302235, 0.16644551, 0.31773537, 0.03195604],
#        [0.2108407 , 0.27302235, 0.16644551, 0.31773537, 0.03195604],
#        [0.2108407 , 0.27302235, 0.16644551, 0.31773537, 0.03195604],
#        ...,
#        [0.2108407 , 0.27302235, 0.16644551, 0.31773537, 0.03195604],
#        [0.2108407 , 0.27302235, 0.16644551, 0.31773537, 0.03195604],
#        [0.2108407 , 0.27302235, 0.16644551, 0.31773537, 0.03195604]],
#       dtype=float32)

# %%
print(np.argmax(raw_predictions[4]))
print(raw_predictions[4])
# Out:
# 4
# [1.6058213e-05 2.8907139e-02 3.3466111e-07 1.7714945e-05 9.7105879e-01]

# %%
data['label'] = list(map(np.argmax, raw_predictions))
data['probs'] = raw_predictions.tolist()

# %%
data
# Out:
#                                                     Water_(g)  Energ_Kcal  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                       4.70         393
# HEARTS OF PALM,CANNED                                   90.20          28
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...      63.89         196
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                 54.73         280
# VINEGAR,DISTILLED                                       94.78          18
# ...                                                       ...         ...
# DRUM,FRESHWATER,RAW                                     77.33         119
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW            63.95         224
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...      74.00         132
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                   79.36          74
# TUNA,FRESH,YELLOWFIN,RAW                                74.03         109
#
#                                                     Protein_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                        12.00
# HEARTS OF PALM,CANNED                                      2.52
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...        24.06
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                   20.43
# VINEGAR,DISTILLED                                          0.00
# ...                                                         ...
# DRUM,FRESHWATER,RAW                                       17.54
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW              20.59
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...         5.06
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                      0.28
# TUNA,FRESH,YELLOWFIN,RAW                                  24.40
#
#                                                     Lipid_Tot_(g)  Ash_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                           6.00     3.90
# HEARTS OF PALM,CANNED                                        0.62     2.04
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...          11.09     1.56
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                     21.35     3.51
# VINEGAR,DISTILLED                                            0.00     0.02
# ...                                                           ...      ...
# DRUM,FRESHWATER,RAW                                          4.93     1.08
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                15.04     0.87
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...           7.59     2.09
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        0.12     0.33
# TUNA,FRESH,YELLOWFIN,RAW                                     0.49     1.64
#
#                                                     Carbohydrt_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                           73.40
# HEARTS OF PALM,CANNED                                         4.62
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...            0.00
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                       0.00
# VINEGAR,DISTILLED                                             0.04
# ...                                                            ...
# DRUM,FRESHWATER,RAW                                           0.00
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                  0.00
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...           11.27
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        19.91
# TUNA,FRESH,YELLOWFIN,RAW                                      0.00
#
#                                                     Fiber_TD_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                           5.2
# HEARTS OF PALM,CANNED                                        2.4
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...           0.0
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                      0.0
# VINEGAR,DISTILLED                                            0.0
# ...                                                          ...
# DRUM,FRESHWATER,RAW                                          0.0
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                 0.0
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...           1.8
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        2.6
# TUNA,FRESH,YELLOWFIN,RAW                                     0.0
#
#                                                     Sugar_Tot_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                          13.75
# HEARTS OF PALM,CANNED                                         NaN
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...           0.00
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                      0.00
# VINEGAR,DISTILLED                                            0.04
# ...                                                           ...
# DRUM,FRESHWATER,RAW                                           NaN
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                 0.00
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...            NaN
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                         NaN
# TUNA,FRESH,YELLOWFIN,RAW                                     0.00
#
#                                                     Calcium_(mg)  Iron_(mg)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                         651.0      47.50
# HEARTS OF PALM,CANNED                                       58.0       3.13
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...          13.0       0.97
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                     10.0       0.95
# VINEGAR,DISTILLED                                            6.0       0.03
# ...                                                          ...        ...
# DRUM,FRESHWATER,RAW                                         60.0       0.90
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                23.0       1.47
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...         119.0       0.64
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                        4.0       0.43
# TUNA,FRESH,YELLOWFIN,RAW                                     4.0       0.77
#
#                                                     ...  Vit_D_µg  Vit_D_IU  \
# Shrt_Desc                                           ...
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                  ...       0.0       0.0
# HEARTS OF PALM,CANNED                               ...       0.0       0.0
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...  ...       NaN       NaN
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD             ...       0.7      29.0
# VINEGAR,DISTILLED                                   ...       0.0       0.0
# ...                                                 ...       ...       ...
# DRUM,FRESHWATER,RAW                                 ...       NaN       NaN
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW        ...       NaN       NaN
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...  ...       0.0       0.0
# APPLES,DEHYD (LO MOIST),SULFURED,STWD               ...       0.0       0.0
# TUNA,FRESH,YELLOWFIN,RAW                            ...       1.7      69.0
#
#                                                     Vit_K_(µg)  FA_Sat_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                         3.0       1.267
# HEARTS OF PALM,CANNED                                      NaN       0.130
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...         0.0       2.866
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                    0.0       7.670
# VINEGAR,DISTILLED                                          0.0       0.000
# ...                                                        ...         ...
# DRUM,FRESHWATER,RAW                                        NaN       1.119
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW               1.6       6.067
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...         NaN       3.530
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                      NaN       0.020
# TUNA,FRESH,YELLOWFIN,RAW                                   0.1       0.172
#
#                                                     FA_Mono_(g)  FA_Poly_(g)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                        1.429        2.186
# HEARTS OF PALM,CANNED                                     0.103        0.202
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...        4.878        1.673
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                  10.140        2.320
# VINEGAR,DISTILLED                                         0.000        0.000
# ...                                                         ...          ...
# DRUM,FRESHWATER,RAW                                       2.190        1.154
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW              6.438        0.572
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...        2.587        1.076
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                     0.005        0.036
# TUNA,FRESH,YELLOWFIN,RAW                                  0.116        0.147
#
#                                                     Cholestrl_(mg)  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                             0.0
# HEARTS OF PALM,CANNED                                          0.0
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...           130.0
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                       58.0
# VINEGAR,DISTILLED                                              0.0
# ...                                                            ...
# DRUM,FRESHWATER,RAW                                           64.0
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW                  80.0
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...            15.0
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                          0.0
# TUNA,FRESH,YELLOWFIN,RAW                                      39.0
#
#                                                     Refuse_Pct  label  \
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                         0.0      0
# HEARTS OF PALM,CANNED                                      0.0      1
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...        29.0      3
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD                   27.0      3
# VINEGAR,DISTILLED                                          0.0      4
# ...                                                        ...    ...
# DRUM,FRESHWATER,RAW                                        0.0      3
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW               9.0      3
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...         0.0      1
# APPLES,DEHYD (LO MOIST),SULFURED,STWD                      0.0      1
# TUNA,FRESH,YELLOWFIN,RAW                                   0.0      3
#
#                                                                                                 probs
# Shrt_Desc
# BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY                  [0.9998394250869751, 3.4087479434674606e-05, 0...
# HEARTS OF PALM,CANNED                               [2.999854586960282e-08, 0.9994088411331177, 4....
# CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD,...  [2.9562095733126625e-05, 7.411003025481477e-05...
# PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD             [0.00026382150826975703, 0.0006710545276291668...
# VINEGAR,DISTILLED                                   [1.605821307748556e-05, 0.028907138854265213, ...
# ...                                                                                               ...
# DRUM,FRESHWATER,RAW                                 [0.00042958883568644524, 0.0012661732034757733...
# BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW        [7.852991984691471e-05, 0.00026358681498095393...
# POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE US...  [0.000639920006506145, 0.8160973191261292, 0.1...
# APPLES,DEHYD (LO MOIST),SULFURED,STWD               [4.736647740699595e-10, 0.9999643564224243, 3....
# TUNA,FRESH,YELLOWFIN,RAW                            [9.45131469052285e-05, 0.0001476598990848288, ...
#
# [7756 rows x 49 columns]

# %%
raw_predictions
# Out:
# array([[9.98343945e-01, 3.79954072e-05, 1.61805528e-03, 2.68236757e-08,
#         1.27627867e-14],
#        [4.86016688e-05, 9.65741575e-01, 2.61100940e-02, 6.88281748e-03,
#         1.21694722e-03],
#        [2.62641057e-04, 9.96801191e-06, 1.55781331e-02, 9.84149158e-01,
#         5.26201802e-08],
#        ...,
#        [2.80091097e-03, 3.65672648e-01, 5.85653663e-01, 4.51869145e-02,
#         6.85835897e-04],
#        [3.90644505e-04, 9.81382370e-01, 1.79375708e-02, 1.75325098e-04,
#         1.14139104e-04],
#        [7.58473834e-05, 5.56117629e-05, 5.41221052e-02, 9.45746303e-01,
#         7.19480582e-08]], dtype=float32)

# %%
data['label'] = clf.predict(data[vars_])

# %%
def predict_sk(model, data, x_names, y_name, file_name = None):
#     from sklearn.preprocessing import MinMaxScaler
    data = data.copy().fillna(0)
    data_x = data[x_names]
    
    scaler = MinMaxScaler()
    data_x = scaler.fit_transform(data_x)
    data[y_name] = list(map(np.argmax, model.predict(data_x)))
    raw = np.array(model.predict_proba(data_x))
    data = data.reset_index()
    return pd.concat([data, pd.DataFrame(np.transpose(raw[:,:, 1]))], axis = 1)

def predict_keras(model, data, x_names, y_name, file_name = None):
#     from sklearn.preprocessing import MinMaxScaler
    data = data.copy().fillna(0)
    data_x = data[x_names]
    
    scaler = MinMaxScaler()
    data_x = scaler.fit_transform(data_x)
    data[y_name] = list(map(np.argmax, model.predict(data_x)))
    raw = model.predict_proba(data_x)
    data = data.reset_index()
    return pd.concat([data, pd.DataFrame(raw)], axis = 1)

# %%
rf_predictions = predict_sk(clf, pd.read_excel("data/train.xlsx", index_col = 0), vars_, 'label')
rf_predictions.to_excel('data/rf_class_predictions.xlsx')
rf_predictions
# Out:
#                                               Shrt_Desc  Water_(g)  \
# 0                    BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY       4.70
# 1                                 HEARTS OF PALM,CANNED      90.20
# 2     CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD...      63.89
# 3               PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD      54.73
# 4                                     VINEGAR,DISTILLED      94.78
# ...                                                 ...        ...
# 7751                                DRUM,FRESHWATER,RAW      77.33
# 7752       BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW      63.95
# 7753  POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE U...      74.00
# 7754              APPLES,DEHYD (LO MOIST),SULFURED,STWD      79.36
# 7755                           TUNA,FRESH,YELLOWFIN,RAW      74.03
#
#       Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0            393        12.00           6.00     3.90           73.40
# 1             28         2.52           0.62     2.04            4.62
# 2            196        24.06          11.09     1.56            0.00
# 3            280        20.43          21.35     3.51            0.00
# 4             18         0.00           0.00     0.02            0.04
# ...          ...          ...            ...      ...             ...
# 7751         119        17.54           4.93     1.08            0.00
# 7752         224        20.59          15.04     0.87            0.00
# 7753         132         5.06           7.59     2.09           11.27
# 7754          74         0.28           0.12     0.33           19.91
# 7755         109        24.40           0.49     1.64            0.00
#
#       Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  ...      GmWt_Desc1  GmWt_2  \
# 0              5.2          13.75         651.0  ...          1 tbsp    15.0
# 1              2.4           0.00          58.0  ...           1 cup    33.0
# 2              0.0           0.00          13.0  ...         1 thigh    85.0
# 3              0.0           0.00          10.0  ...           1 cup    85.0
# 4              0.0           0.04           6.0  ...          1 tbsp   238.0
# ...            ...            ...           ...  ...             ...     ...
# 7751           0.0           0.00          60.0  ...            3 oz   198.0
# 7752           0.0           0.00          23.0  ...            3 oz     0.0
# 7753           1.8           0.00         119.0  ...           1 cup     0.0
# 7754           2.6           0.00           4.0  ...           1 cup     0.0
# 7755           0.0           0.00           4.0  ...  1 oz, boneless    16.0
#
#                   GmWt_Desc2  Refuse_Pct  label    0         1         2  \
# 0                      .5 oz         0.0      0  1.0  0.000000  0.000000
# 1                    1 piece         0.0      1  0.0  0.989801  0.009108
# 2         1 serving,  (3 oz)        29.0      3  0.0  0.000000  0.021281
# 3                       3 oz        27.0      3  0.0  0.000000  0.030508
# 4                      1 cup         0.0      4  0.0  0.000000  0.125000
# ...                      ...         ...    ...  ...       ...       ...
# 7751                1 fillet         0.0      3  0.0  0.000000  0.054131
# 7752                       0         9.0      3  0.0  0.000000  0.052904
# 7753                       0         0.0      1  0.0  0.900000  0.100000
# 7754                       0         0.0      1  0.0  0.996154  0.003846
# 7755  1 cubic inch, boneless         0.0      3  0.0  0.000000  0.042566
#
#              3         4
# 0     0.000000  0.000000
# 1     0.000000  0.001091
# 2     0.978719  0.000000
# 3     0.969492  0.000000
# 4     0.000000  0.875000
# ...        ...       ...
# 7751  0.945869  0.000000
# 7752  0.947096  0.000000
# 7753  0.000000  0.000000
# 7754  0.000000  0.000000
# 7755  0.957434  0.000000
#
# [7756 rows x 58 columns]

# %%
nn_predictions = predict_keras(model, pd.read_excel("data/train.xlsx", index_col = 0), vars_, 'label')
nn_predictions.to_excel('data/dnn_class_predictions.xlsx')
nn_predictions
# Out:
#                                               Shrt_Desc  Water_(g)  \
# 0                    BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY       4.70
# 1                                 HEARTS OF PALM,CANNED      90.20
# 2     CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD...      63.89
# 3               PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD      54.73
# 4                                     VINEGAR,DISTILLED      94.78
# ...                                                 ...        ...
# 7751                                DRUM,FRESHWATER,RAW      77.33
# 7752       BEEF,LOIN,TOP LOIN,LN & FAT,1/8" FAT,SEL,RAW      63.95
# 7753  POTATOES,AU GRATIN,HOME-PREPARED FROM RECIPE U...      74.00
# 7754              APPLES,DEHYD (LO MOIST),SULFURED,STWD      79.36
# 7755                           TUNA,FRESH,YELLOWFIN,RAW      74.03
#
#       Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0            393        12.00           6.00     3.90           73.40
# 1             28         2.52           0.62     2.04            4.62
# 2            196        24.06          11.09     1.56            0.00
# 3            280        20.43          21.35     3.51            0.00
# 4             18         0.00           0.00     0.02            0.04
# ...          ...          ...            ...      ...             ...
# 7751         119        17.54           4.93     1.08            0.00
# 7752         224        20.59          15.04     0.87            0.00
# 7753         132         5.06           7.59     2.09           11.27
# 7754          74         0.28           0.12     0.33           19.91
# 7755         109        24.40           0.49     1.64            0.00
#
#       Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  ...      GmWt_Desc1  GmWt_2  \
# 0              5.2          13.75         651.0  ...          1 tbsp    15.0
# 1              2.4           0.00          58.0  ...           1 cup    33.0
# 2              0.0           0.00          13.0  ...         1 thigh    85.0
# 3              0.0           0.00          10.0  ...           1 cup    85.0
# 4              0.0           0.04           6.0  ...          1 tbsp   238.0
# ...            ...            ...           ...  ...             ...     ...
# 7751           0.0           0.00          60.0  ...            3 oz   198.0
# 7752           0.0           0.00          23.0  ...            3 oz     0.0
# 7753           1.8           0.00         119.0  ...           1 cup     0.0
# 7754           2.6           0.00           4.0  ...           1 cup     0.0
# 7755           0.0           0.00           4.0  ...  1 oz, boneless    16.0
#
#                   GmWt_Desc2  Refuse_Pct  label         0         1         2  \
# 0                      .5 oz         0.0      0  0.999849  0.000011  0.000140
# 1                    1 piece         0.0      1  0.000066  0.991043  0.000359
# 2         1 serving,  (3 oz)        29.0      3  0.000002  0.000060  0.059790
# 3                       3 oz        27.0      3  0.000010  0.000049  0.091198
# 4                      1 cup         0.0      4  0.000006  0.035176  0.332025
# ...                      ...         ...    ...       ...       ...       ...
# 7751                1 fillet         0.0      3  0.000002  0.000137  0.074032
# 7752                       0         9.0      3  0.000003  0.000110  0.059991
# 7753                       0         0.0      1  0.001335  0.938747  0.059833
# 7754                       0         0.0      1  0.000017  0.999965  0.000006
# 7755  1 cubic inch, boneless         0.0      3  0.000002  0.000151  0.060383
#
#                  3             4
# 0     1.473542e-07  5.795245e-08
# 1     4.691100e-08  8.532343e-03
# 2     9.401181e-01  2.944955e-05
# 3     9.086630e-01  7.954174e-05
# 4     9.434477e-05  6.326982e-01
# ...            ...           ...
# 7751  9.257727e-01  5.684254e-05
# 7752  9.398049e-01  9.091821e-05
# 7753  4.184984e-05  4.245256e-05
# 7754  8.262457e-11  1.292823e-05
# 7755  9.394131e-01  5.183411e-05
#
# [7756 rows x 58 columns]
